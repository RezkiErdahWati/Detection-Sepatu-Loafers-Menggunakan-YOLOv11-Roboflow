# %% [markdown]
# ### 1.1 Connect GPU Environment
#
# - Click `Connect` button in top right Google Colab notebook,<br>
# <img src="https://github.com/Muhammad-Yunus/Belajar-OpenCV-ObjectDetection/blob/main/Pertemuan%205/resource/cl-connect-gpu.png?raw=1" width="250px">
# - If connecting process completed, it will turn to something look like this<br>
# <img src="https://github.com/Muhammad-Yunus/Belajar-OpenCV-ObjectDetection/blob/main/Pertemuan%205/resource/cl-connect-gpu-success.png?raw=1" width="250px">

# %% [markdown]
# - Check GPU connected into Colab environment is active

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 19.8 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.4.41 🚀 Python-3.12.13 torch-2.10.0+cpu CPU (AMD EPYC 7B12)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 20.6/107.7 GB disk)

# %%
# !yolo detect train \
model=yolo11n.pt \
data="/content/drive/MyDrive/FOLDER TUGAS MACHINE LEARNING (ML)/data.yaml" \
epochs=25 \
imgsz=320
# Out:
# Ultralytics 8.4.41 🚀 Python-3.12.13 torch-2.10.0+cpu CPU (AMD EPYC 7B12)
# ...

# %%
# !yolo detect predict model=/content/runs/detect/train-2/weights/best.pt source='/content/drive/MyDrive/FOLDER TUGAS MACHINE LEARNING (ML)/Image/valid/images/image182_jpeg.rf.44da8422d9f4c85cf820e6a8320150d0.jpg' save=true
# Out:
# Ultralytics 8.4.41 🚀 Python-3.12.13 torch-2.10.0+cpu CPU (AMD EPYC 7B12)
# YOLO11n summary (fused): 101 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
#
# image 1/1 /content/drive/MyDrive/FOLDER TUGAS MACHINE LEARNING (ML)/Image/valid/images/image182_jpeg.rf.44da8422d9f4c85cf820e6a8320150d0.jpg: 320x320 1 Loafers, 58.5ms
# Speed: 1.7ms preprocess, 58.5ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 320)
# Results saved to /content/runs/detect/predict-11
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo detect predict model=/content/runs/detect/train-2/weights/best.pt source='https://media.karousell.com/media/photos/products/2022/10/23/sepatu_loafer_tods_1666498545_8e864cc6_progressive.jpg' save=true
# Out:
# Ultralytics 8.4.41 🚀 Python-3.12.13 torch-2.10.0+cpu CPU (AMD EPYC 7B12)
# YOLO11n summary (fused): 101 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
#
# Found https://media.karousell.com/media/photos/products/2022/10/23/sepatu_loafer_tods_1666498545_8e864cc6_progressive.jpg locally at sepatu_loafer_tods_1666498545_8e864cc6_progressive.jpg
# image 1/1 /content/sepatu_loafer_tods_1666498545_8e864cc6_progressive.jpg: 320x256 1 Loafers, 51.8ms
# Speed: 3.0ms preprocess, 51.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 256)
# Results saved to /content/runs/detect/predict-12
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
